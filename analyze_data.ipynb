# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # CNA

# %%
cna_df = pd.read_csv('data/CNA_test_data.csv')
cna_df.head(3)
# Out:
#                 bins     CRC_1     CRC_2     CRC_3     CRC_4     CRC_5  \
# 0  1:1000001-2000000  0.896475  0.828850  0.851508  0.927454  0.895133
# 1  1:2000001-3000000  0.983415  1.001451  1.093219  1.066098  1.077617
# 2  1:3000001-4000000  1.118625  1.107329  1.137303  1.130093  1.092212
#
#       CRC_6     CRC_7     CRC_8     CRC_9  ...  Breast_41  Breast_42  \
# 0  0.853351  0.883020  0.861244  0.952042  ...   0.895374   0.932478
# 1  1.026893  1.104132  1.002475  1.072812  ...   0.963836   1.048706
# 2  1.126741  1.099327  1.070323  1.129020  ...   1.104951   1.150284
#
#    Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  \
# 0   0.837540   0.796464   0.932748   0.867180   0.806904   0.849950
# 1   1.070006   1.050492   1.140593   1.035193   1.002272   0.966441
# 2   1.157951   1.029828   1.195422   1.109486   1.081973   1.090978
#
#    Breast_49  Breast_50
# 0   0.852024   0.937161
# 1   1.050553   1.031910
# 2   1.141446   1.114758
#
# ...

# %%
cna_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2691 entries, 0 to 2690
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 6.2+ MB

# %%
cna_df.describe()
# Out:
#              CRC_1        CRC_2        CRC_3        CRC_4        CRC_5  \
# count  2691.000000  2691.000000  2691.000000  2691.000000  2691.000000
# mean      1.023979     1.027221     1.027243     1.008166     1.030397
# std       0.498076     0.509294     0.492813     0.397813     0.469642
# min       0.417178     0.407919     0.415329     0.391534     0.423365
# 25%       0.936439     0.935813     0.930239     0.958646     0.940444
# 50%       1.003830     1.005412     1.005344     1.002503     1.003968
# 75%       1.082873     1.089673     1.094289     1.054834     1.087470
# max      20.661276    21.612506    20.272877    14.587554    18.855266
#
#              CRC_6        CRC_7        CRC_8        CRC_9       CRC_10  ...  \
# count  2691.000000  2691.000000  2691.000000  2691.000000  2691.000000  ...
# mean      1.024055     1.061346     1.015925     1.009645     0.999488  ...
# std       0.481997     0.559954     0.469427     0.393248     0.373585  ...
# ...

# %%
# Check null
for key in cna_df.keys():
    if cna_df[key].isnull().sum() > 0:
        print(cna_df[key].isnull().sum())

# %%
cna_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %%
cna_df[cna_df.CRC_1 == cna_df.CRC_1.max()]
# Out:
#                      bins      CRC_1      CRC_2      CRC_3      CRC_4  \
# 1252  7:58000001-59000000  20.661276  21.612506  20.272877  14.587554
#
#           CRC_5      CRC_6     CRC_7      CRC_8      CRC_9  ...  Breast_41  \
# 1252  18.855266  19.719206  21.19886  17.405739  14.503236  ...   15.52509
#
#       Breast_42  Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  \
# 1252  13.683005  22.363454  29.206052  19.066993  17.152869  21.182084
#
#       Breast_48  Breast_49  Breast_50
# 1252  24.268945  19.360937  12.668391
#
# [1 rows x 301 columns]

# %% [markdown]
# # GWFP total norm

# %%
Gtotal_df = pd.read_csv('data/GWFP_total_norm_test_data.csv')
Gtotal_df.head(3)
# Out:
#                   bins     CRC_1     CRC_2     CRC_3     CRC_4     CRC_5  \
# 0          1:1-5000000  1.531551  1.711940  1.472429  0.719191  1.901539
# 1   1:5000001-10000000  1.065820  1.064210  1.015498  0.847796  1.205166
# 2  1:10000001-15000000  0.692325  0.743852  0.762558  0.590586  0.730789
#
#       CRC_6     CRC_7     CRC_8     CRC_9  ...  Breast_41  Breast_42  \
# 0  1.496063  1.902349  0.895481  0.879286  ...   0.781366   0.730143
# 1  1.061855  1.149125  0.957786  0.838067  ...   0.838129   0.805367
# 2  0.718655  0.928326  0.560544  0.403702  ...   0.540579   0.545588
#
#    Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  \
# 0   1.796621   2.225653   1.817794   0.949293   1.684398   2.146071
# 1   1.090699   1.107328   1.125770   0.995494   1.116419   1.254769
# 2   0.976322   0.858465   0.791649   0.613307   0.860495   0.733927
#
#    Breast_49  Breast_50
# 0   1.253277   0.753613
# 1   0.932326   0.778801
# 2   0.609050   0.452968
#
# ...

# %%
Gtotal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 1.4+ MB

# %%
Gtotal_df.describe()
# Out:
#               CRC_1         CRC_2         CRC_3         CRC_4         CRC_5  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean  -2.356392e-16  1.102670e-16  2.960595e-16  2.295971e-16  1.510508e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.398612e+00 -4.206487e+00 -4.234055e+00 -4.865322e+00 -4.236446e+00
# 25%   -3.570672e-01 -4.075049e-01 -4.321573e-01 -1.194045e-01 -3.617967e-01
# 50%    4.074461e-02  1.418402e-03  2.390658e-02  2.226205e-01 -1.603525e-03
# 75%    5.776288e-01  5.016358e-01  5.752430e-01  5.716657e-01  4.994815e-01
# max    3.113574e+00  3.447404e+00  3.168218e+00  1.850541e+00  3.791696e+00
#
#               CRC_6         CRC_7         CRC_8         CRC_9        CRC_10  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean   2.507442e-16 -1.268826e-16  1.510508e-16 -1.812609e-16 -2.416812e-16
# ...

# %%
# Check null
for key in Gtotal_df.keys():
    if Gtotal_df[key].isnull().sum() > 0:
        print(Gtotal_df[key].isnull().sum())

# %%
Gtotal_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # GWFP short norm

# %%
Gshort_df = pd.read_csv('data/GWFP_short_norm_test_data.csv')
Gshort_df.head(3)
# Out:
#                   bins     CRC_1     CRC_2     CRC_3     CRC_4     CRC_5  \
# 0          1:1-5000000  1.540670  2.059816  1.403368  0.691356  2.202027
# 1   1:5000001-10000000  1.127086  1.194364  0.970993  0.763338  1.053061
# 2  1:10000001-15000000  0.688588  0.786863  0.842533  0.625544  0.856702
#
#       CRC_6     CRC_7     CRC_8     CRC_9  ...  Breast_41  Breast_42  \
# 0  1.697434  1.718046  0.768961  1.138515  ...   0.868141   0.560601
# 1  0.991708  1.158355  1.026092  0.904564  ...   0.796865   0.700591
# 2  0.872470  0.808456  0.483988  0.389486  ...   0.647275   0.251009
#
#    Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  \
# 0   1.671216   2.116157   1.872455   1.074191   1.344127   2.192616
# 1   1.094969   1.153954   1.084907   0.963951   0.988078   1.292908
# 2   0.837497   0.833654   0.667318   0.614014   0.878903   0.623124
#
#    Breast_49  Breast_50
# 0   1.081048   0.806777
# 1   1.036462   0.912896
# 2   0.501431   0.426517
#
# ...

# %%
Gshort_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 1.4+ MB

# %%
Gshort_df.describe()
# Out:
#               CRC_1         CRC_2         CRC_3         CRC_4         CRC_5  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean  -3.927320e-17 -9.063045e-18  6.344132e-17 -1.450087e-16  8.911994e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.221261e+00 -3.940138e+00 -4.184085e+00 -4.823480e+00 -3.959404e+00
# 25%   -4.196991e-01 -4.404883e-01 -4.172544e-01 -1.657418e-01 -4.461673e-01
# 50%    1.129917e-04 -3.977978e-02 -7.594872e-03  2.229600e-01 -5.742936e-02
# 75%    5.536337e-01  5.278097e-01  5.461896e-01  5.569043e-01  4.779146e-01
# max    3.598621e+00  3.658769e+00  3.407540e+00  2.202974e+00  4.128469e+00
#
#               CRC_6         CRC_7         CRC_8         CRC_9        CRC_10  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean  -7.552538e-18 -2.839754e-16  2.718914e-16 -3.383537e-16  1.812609e-16
# ...

# %%
# Check null
for key in Gshort_df.keys():
    if Gshort_df[key].isnull().sum() > 0:
        print(Gshort_df[key].isnull().sum())

# %%
Gshort_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # GWFP long norm

# %%
Glong_df = pd.read_csv('data/GWFP_long_norm_test_data.csv')
Glong_df.head(3)
# Out:
#                   bins     CRC_1     CRC_2     CRC_3     CRC_4     CRC_5  \
# 0          1:1-5000000  1.526133  1.616996  1.486215  0.724332  1.825458
# 1   1:5000001-10000000  1.052816  1.026727  1.024222  0.866978  1.234201
# 2  1:10000001-15000000  0.691197  0.729651  0.740624  0.580119  0.699198
#
#       CRC_6     CRC_7     CRC_8     CRC_9  ...  Breast_41  Breast_42  \
# 0  1.434199  1.952045  0.928096  0.779993  ...   0.755632   0.777005
# 1  1.078198  1.144086  0.935459  0.808241  ...   0.845691   0.833094
# 2  0.672796  0.961282  0.580218  0.405934  ...   0.510561   0.629527
#
#    Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  \
# 0   1.820270   2.251612   1.797967   0.911559   1.786238   2.127317
# 1   1.088358   1.092206   1.133354   1.000118   1.153035   1.240642
# 2   1.003852   0.863647   0.822396   0.610678   0.851435   0.764191
#
#    Breast_49  Breast_50
# 0   1.294431   0.727725
# 1   0.901903   0.721045
# 2   0.635336   0.460283
#
# ...

# %%
Glong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 1.4+ MB

# %%
Glong_df.describe()
# Out:
#               CRC_1         CRC_2         CRC_3         CRC_4         CRC_5  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean  -1.540718e-16  1.419877e-16 -1.147986e-16 -4.229421e-16 -1.208406e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.417272e+00 -4.253652e+00 -4.236366e+00 -4.862893e+00 -4.280407e+00
# 25%   -3.395584e-01 -3.818350e-01 -4.362657e-01 -1.075074e-01 -3.536047e-01
# 50%    4.712319e-02  2.191151e-02  2.756431e-02  2.278803e-01  1.458439e-02
# 75%    5.614537e-01  5.061161e-01  5.809203e-01  5.719547e-01  4.989453e-01
# max    3.024132e+00  3.378578e+00  3.100438e+00  1.756033e+00  3.725500e+00
#
#               CRC_6         CRC_7         CRC_8         CRC_9        CRC_10  \
# count  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02  5.880000e+02
# mean  -2.265761e-16 -2.960595e-16 -2.960595e-16  2.054290e-16 -1.450087e-16
# ...

# %%
# Check null
for key in Glong_df.keys():
    if Glong_df[key].isnull().sum() > 0:
        print(Glong_df[key].isnull().sum())

# %%
Glong_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # GWFP ratio

# %%
Gratio_df = pd.read_csv('data/GWFP_ratio_test_data.csv')
Gratio_df.head(3)
# Out:
#                   bins     CRC_1     CRC_2     CRC_3     CRC_4     CRC_5  \
# 0          1:1-5000000  0.162797  0.255559  0.245705  0.251516  0.226677
# 1   1:5000001-10000000  0.164158  0.243282  0.246626  0.248476  0.204231
# 2  1:10000001-15000000  0.161379  0.237409  0.254097  0.255071  0.217128
#
#       CRC_6     CRC_7     CRC_8     CRC_9  ...  Breast_41  Breast_42  \
# 0  0.285126  0.288458  0.274022  0.369468  ...   0.261958   0.281845
# 1  0.267759  0.302923  0.286087  0.353131  ...   0.254711   0.286214
# 2  0.282038  0.293009  0.276814  0.345170  ...   0.263120   0.273025
#
#    Breast_43  Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  \
# 0   0.203863   0.266514   0.258658   0.272697   0.307526   0.283876
# 1   0.209947   0.276534   0.251718   0.263464   0.323401   0.282067
# 2   0.202456   0.270096   0.245282   0.264824   0.336391   0.268343
#
#    Breast_49  Breast_50
# 0   0.252635   0.388889
# 1   0.268170   0.396658
# 2   0.255280   0.380605
#
# ...

# %%
Gratio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 1.4+ MB

# %%
Gratio_df.describe()
# Out:
#             CRC_1       CRC_2       CRC_3       CRC_4       CRC_5       CRC_6  \
# count  588.000000  588.000000  588.000000  588.000000  588.000000  588.000000
# mean     0.160438    0.231833    0.248906    0.253263    0.207231    0.269319
# std      0.007878    0.013835    0.009943    0.010993    0.012430    0.011242
# min      0.143541    0.198630    0.221753    0.230233    0.132653    0.240815
# 25%      0.155480    0.223361    0.243211    0.247337    0.199500    0.262135
# 50%      0.159533    0.230341    0.248106    0.252198    0.206558    0.268056
# 75%      0.163291    0.238795    0.253452    0.257345    0.212939    0.275294
# max      0.236916    0.329819    0.360673    0.379195    0.311961    0.366673
#
#             CRC_7       CRC_8       CRC_9      CRC_10  ...   Breast_41  \
# count  588.000000  588.000000  588.000000  588.000000  ...  588.000000
# mean     0.306687    0.282048    0.345686    0.249231  ...    0.256247
# ...

# %%
# Check null
for key in Gratio_df.keys():
    if Gratio_df[key].isnull().sum() > 0:
        print(Gratio_df[key].isnull().sum())

# %%
Gratio_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # GWFP flen range 100-250

# %%
Gflen_df = pd.read_csv('data/GWFP_flen_range_100_250_test_data.csv', index_col=0)
Gflen_df.head(3)
# Out:
#          CRC_1     CRC_2     CRC_3     CRC_4     CRC_5     CRC_6     CRC_7  \
# flen
# 100   0.000181  0.000445  0.000492  0.000523  0.000354  0.000477  0.000729
# 101   0.000214  0.000507  0.000564  0.000602  0.000421  0.000539  0.000832
# 102   0.000242  0.000598  0.000637  0.000676  0.000499  0.000624  0.000957
#
#          CRC_8     CRC_9    CRC_10  ...  Breast_41  Breast_42  Breast_43  \
# flen                                ...
# 100   0.000596  0.000717  0.000445  ...   0.000744   0.000689   0.000381
# 101   0.000701  0.000830  0.000514  ...   0.000810   0.000776   0.000437
# 102   0.000760  0.000948  0.000565  ...   0.000901   0.000862   0.000499
#
#       Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  Breast_49  \
# flen
# 100    0.000566   0.000470   0.000597   0.000831   0.000623   0.000556
# 101    0.000626   0.000557   0.000682   0.000968   0.000729   0.000642
# 102    0.000732   0.000610   0.000790   0.001042   0.000845   0.000725
#
#       Breast_50
# flen
# ...

# %%
Gflen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 100 to 250
# Columns: 300 entries, CRC_1 to Breast_50
# dtypes: float64(300)
# memory usage: 355.1 KB

# %%
Gflen_df.describe()
# Out:
#             CRC_1       CRC_2       CRC_3       CRC_4       CRC_5       CRC_6  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean     0.006623    0.006623    0.006623    0.006623    0.006623    0.006623
# std      0.007175    0.007209    0.007103    0.007158    0.007026    0.007524
# min      0.000181    0.000397    0.000351    0.000500    0.000354    0.000327
# 25%      0.001027    0.001026    0.001038    0.001093    0.001141    0.000911
# 50%      0.003234    0.002923    0.002996    0.003064    0.003089    0.002888
# 75%      0.010491    0.010996    0.011186    0.010755    0.010573    0.011137
# max      0.023729    0.024796    0.023852    0.025113    0.023959    0.025968
#
#             CRC_7       CRC_8       CRC_9      CRC_10  ...   Breast_41  \
# count  151.000000  151.000000  151.000000  151.000000  ...  151.000000
# mean     0.006623    0.006623    0.006623    0.006623  ...    0.006623
# ...

# %%
# Check null
for key in Gflen_df.keys():
    if Gflen_df[key].isnull().sum() > 0:
        print(Gflen_df[key].isnull().sum())

# %%
Gflen_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # GWMD

# %%
Gwmd_df = pd.read_csv('data/GWMD_test_data.csv')
Gwmd_df.head(3)
# Out:
#      bins      CRC_1      CRC_2      CRC_3      CRC_4      CRC_5      CRC_6  \
# 0  chr1_1  60.927221  65.413050  65.750431  65.589354  62.358146  55.663750
# 1  chr1_2  73.222127  76.970803  76.350943  78.176306  74.688699  69.864555
# 2  chr1_3  74.013700  77.656649  76.044129  73.843518  76.255121  71.555632
#
#        CRC_7      CRC_8      CRC_9  ...  Breast_41  Breast_42  Breast_43  \
# 0  50.075307  66.729089  61.559932  ...  64.813943  65.913201  48.222894
# 1  66.419844  79.801123  75.941598  ...  77.222151  80.184622  62.558948
# 2  67.883985  75.690572  76.848814  ...  78.461891  80.120249  68.675853
#
#    Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  Breast_49  Breast_50
# 0  60.034330  52.200165  59.549216  60.300323  57.236842  67.371417  70.616659
# 1  72.728064  69.465779  75.416472  74.700936  71.404417  78.412432  81.278266
# 2  71.581100  73.035318  75.197302  74.880902  73.893585  78.541168  79.444987
#
# [3 rows x 301 columns]

# %%
Gwmd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2734 entries, 0 to 2733
# Columns: 301 entries, bins to Breast_50
# dtypes: float64(300), object(1)
# memory usage: 6.3+ MB

# %%
Gwmd_df.describe()
# Out:
#              CRC_1        CRC_2        CRC_3        CRC_4        CRC_5  \
# count  2734.000000  2734.000000  2734.000000  2734.000000  2734.000000
# mean     78.052269    78.492174    76.470380    76.063142    76.378334
# std       5.812137     5.830595     5.649668     4.803543     6.398124
# min      24.989110    46.688122    42.501942    46.153846    42.465753
# 25%      74.949205    75.314825    73.944401    74.054606    72.874191
# 50%      78.999319    79.528736    77.312677    76.683814    77.289539
# 75%      82.153368    82.688260    80.144846    79.111069    80.762094
# max      90.858726    92.401216    90.167795    88.875276    92.011834
#
#              CRC_6        CRC_7        CRC_8        CRC_9       CRC_10  ...  \
# count  2734.000000  2734.000000  2734.000000  2734.000000  2734.000000  ...
# mean     75.859846    72.172095    78.398756    78.158079    79.776668  ...
# std       6.208787     7.590061     4.782093     5.314197     4.420361  ...
# ...

# %%
# Check null
for key in Gwmd_df.keys():
    if Gwmd_df[key].isnull().sum() > 0:
        print(Gwmd_df[key].isnull().sum())

# %%
Gwmd_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # TMD

# %%
tmd_df = pd.read_csv('data/TMD_test_data.csv')
tmd_df.head(3)
# Out:
#    region      CRC_1      CRC_2      CRC_3      CRC_4      CRC_5      CRC_6  \
# 0       1  90.804598  86.138614  97.161572  91.605840  97.674419  96.162047
# 1       2   3.188406   0.675676  15.909091   5.813953   6.896552   5.742297
# 2       3   9.005629   4.258065   4.666667   4.352806   5.208333   4.827586
#
#        CRC_7      CRC_8      CRC_9  ...  Breast_41  Breast_42  Breast_43  \
# 0  92.241379  92.006950  95.232490  ...  96.220302  96.703297  98.160920
# 1  13.135593  10.267857   8.786127  ...   5.934959  14.465409  10.050251
# 2   4.690832   6.568878   3.209671  ...   3.419316  12.733447   4.962244
#
#    Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  Breast_49  Breast_50
# 0  96.661102  97.288136  97.510373  96.756757  94.475138  96.544720  96.934866
# 1  10.619469  13.061224   6.407767   9.230769   4.663212  13.422820  12.925170
# 2   2.667628   0.965406   2.418380   1.658031   2.272727   5.115512   2.314815
#
# [3 rows x 301 columns]

# %%
tmd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Columns: 301 entries, region to Breast_50
# dtypes: float64(300), int64(1)
# memory usage: 1.0 MB

# %%
tmd_df.describe()
# Out:
#            region       CRC_1       CRC_2       CRC_3       CRC_4       CRC_5  \
# count  446.000000  446.000000  446.000000  446.000000  446.000000  446.000000
# mean   226.354260   22.747873   24.441002   23.520013   22.695524   22.533532
# std    130.389202   34.316994   35.538605   33.419460   33.498472   33.957135
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    114.250000    1.766851    1.892801    2.837970    2.290810    1.400518
# 50%    226.500000    4.708615    5.693394    6.325569    5.272028    5.238941
# 75%    338.750000   18.627717   23.596491   24.169036   18.804862   23.257309
# max    451.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#             CRC_6       CRC_7       CRC_8       CRC_9  ...   Breast_41  \
# count  446.000000  446.000000  446.000000  446.000000  ...  446.000000
# mean    23.663531   22.763369   24.310680   22.798602  ...   23.271422
# ...

# %%
# Check null
for key in tmd_df.keys():
    if tmd_df[key].isnull().sum() > 0:
        print(tmd_df[key].isnull().sum())

# %%
tmd_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # MOTIF_END

# %%
motif_df = pd.read_csv('data/MOTIF_END_test_data.csv', index_col=0)
motif_df.head(3)
# Out:
#           CRC_1     CRC_2     CRC_3     CRC_4     CRC_5     CRC_6     CRC_7  \
# 4-mer
# AAAA   0.012257  0.012906  0.012025  0.012372  0.012958  0.012637  0.012322
# AAAC   0.005041  0.005200  0.005033  0.005029  0.005371  0.005076  0.005331
# AAAG   0.007677  0.007984  0.007795  0.007887  0.007939  0.007885  0.008108
#
#           CRC_8     CRC_9    CRC_10  ...  Breast_41  Breast_42  Breast_43  \
# 4-mer                                ...
# AAAA   0.012796  0.012638  0.012705  ...   0.013125   0.012856   0.011522
# AAAC   0.005192  0.005174  0.005165  ...   0.005364   0.005192   0.004924
# AAAG   0.008297  0.008267  0.008056  ...   0.008361   0.008134   0.007480
#
#        Breast_44  Breast_45  Breast_46  Breast_47  Breast_48  Breast_49  \
# 4-mer
# AAAA    0.010640   0.012138   0.012668   0.011905   0.012347   0.012939
# AAAC    0.004515   0.005042   0.005190   0.004872   0.005117   0.005210
# AAAG    0.007185   0.007541   0.008051   0.007554   0.007783   0.008254
#
# ...

# %%
motif_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 256 entries, AAAA to TTTT
# Columns: 300 entries, CRC_1 to Breast_50
# dtypes: float64(300)
# memory usage: 602.0+ KB

# %%
motif_df.describe()
# Out:
#             CRC_1       CRC_2       CRC_3       CRC_4       CRC_5       CRC_6  \
# count  256.000000  256.000000  256.000000  256.000000  256.000000  256.000000
# mean     0.003906    0.003906    0.003906    0.003906    0.003906    0.003906
# std      0.002171    0.002218    0.002177    0.002192    0.002189    0.002183
# min      0.000312    0.000341    0.000326    0.000281    0.000347    0.000332
# 25%      0.002581    0.002615    0.002600    0.002792    0.002617    0.002595
# 50%      0.003804    0.003730    0.003827    0.003734    0.003735    0.003742
# 75%      0.005185    0.005187    0.005175    0.005243    0.005175    0.005162
# max      0.012257    0.012906    0.012025    0.012372    0.012958    0.012637
#
#             CRC_7       CRC_8       CRC_9      CRC_10  ...   Breast_41  \
# count  256.000000  256.000000  256.000000  256.000000  ...  256.000000
# mean     0.003906    0.003906    0.003906    0.003906  ...    0.003906
# ...

# %%
# Check null
for key in motif_df.keys():
    if motif_df[key].isnull().sum() > 0:
        print(motif_df[key].isnull().sum())

# %%
motif_df.boxplot(column=['CRC_1'], return_type='axes')
# Out:
# <AxesSubplot: >
